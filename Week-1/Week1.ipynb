# %% [markdown]
# # Assignment - 1: Pandas Basics
# Dataset: `Combined_dataset.csv`

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 1: Load a CSV dataset into a Pandas DataFrame

# %%
df = pd.read_csv('Combined_dataset.csv')
# print(df)

# %% [markdown]
# ### Step 2: Explore Data

# %%
# Shape
print('Shape')
print(df.shape)

# Colums as list
print('\nColumns')
print(df.columns.tolist())

# Data types
print('\nData Types')
print(df.dtypes)

# Head gives first 5 rows and tail gives last 5 rows of the dataframe
print('\nHead')
display(df.head())
print('\nTail')
display(df.tail())
# Out:
# Shape
# (1000, 24)
#
# Columns
# ['product_id', 'title', 'product_description', 'rating', 'ratings_count', 'initial_price', 'discount', 'final_price', 'currency', 'images', 'delivery_options', 'product_details', 'breadcrumbs', 'product_specifications', 'amount_of_stars', 'what_customers_said', 'seller_name', 'sizes', 'videos', 'seller_information', 'variations', 'best_offer', 'more_offers', 'category']
#
# Data Types
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# ...

# %% [markdown]
# ### Step 3: Handle Missing Values

# %%
print("Missing values before:\n")
print(df.isnull().sum()[df.isnull().sum() > 0])

# DROP colums that have more than 50% missing values
half_count = len(df) * 0.5 
df = df.dropna(axis=1, thresh=half_count)

# 2. FILL missing data in columns with appropriate values 
numeric_cols = df.select_dtypes(include=['number']).columns
text_cols = df.select_dtypes(include=['object','str']).columns

for col in text_cols:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna('Not Available')

for col in numeric_cols:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(0)

# 4. VERIFY the data
print("\nMissing Values AFTER Cleaning:",df.isnull().sum().sum())
# Out:
# Missing values before:
#
# discount               121
# what_customers_said    573
# seller_name            301
# videos                 781
# seller_information     301
# variations             562
# dtype: int64
#
# Missing Values AFTER Cleaning: 0

# %% [markdown]
# ### Step 4: Perform Basic Operations

# %%
# Filter rows to get products with an initial price greater than 1000
premium_products = df[df['initial_price'] > 1000]

# Select columns to view only title, category, and price
selected_cols = premium_products[['title', 'category', 'initial_price']]

display(selected_cols)
# Out:
#                  title   category  initial_price
# 0          Lino Perros  backpacks           3995
# 1       Tommy Hilfiger  backpacks           2899
# 2                Lavie  backpacks           2999
# 3               F Gear  backpacks           1675
# 4            MYTRIDENT  bath-robe           2899
# ..                 ...        ...            ...
# 994  French Connection    watches           6250
# 995              KREDO    watches          11890
# 996              GUESS    watches           8900
# 997           GIORDANO    watches           7950
# 998           Fastrack    watches           3295
#
# [832 rows x 3 columns]

# %% [markdown]
# ### Step 5: Remove Duplicates

# %%
initial_len = len(df)
# print(initial_len)
df = df.drop_duplicates()
print(f"Dropped {initial_len - len(df)} rows.")
# Out:
# Dropped 0 rows.

# %% [markdown]
# ### Step 6: Create a Derived Column (total_amount = price * quantity)
# *Note: Since the provided Kaggle dataset lacked a 'quantity' column, I generated a mock column to successfully demonstrate Step 6*

# %%
# 1. Create a dummy quantity column (random numbers between 1 and 5)
np.random.seed(42)
df['quantity'] = np.random.randint(1, 6, size=len(df))

# 2. Create the derived column
df['total_amount'] = df['initial_price'] * df['quantity']

display(df[['title', 'initial_price', 'quantity', 'total_amount']])
# Out:
#               title  initial_price  quantity  total_amount
# 0       Lino Perros           3995         4         15980
# 1    Tommy Hilfiger           2899         5         14495
# 2             Lavie           2999         3          8997
# 3            F Gear           1675         5          8375
# 4         MYTRIDENT           2899         5         14495
# ..              ...            ...       ...           ...
# 995           KREDO          11890         2         23780
# 996           GUESS           8900         1          8900
# 997        GIORDANO           7950         1          7950
# 998        Fastrack           3295         4         13180
# 999         BOLDFIT            699         3          2097
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Step 7: Save the Cleaned Dataset

# %%
df.to_csv('Cleaned_Combined_dataset.csv', index=False)
print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!
